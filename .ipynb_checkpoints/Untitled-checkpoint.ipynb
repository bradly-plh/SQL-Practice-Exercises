# %% [markdown]
# # SQL Select Exercises

# %%
import pandas as pd
import sqlite3
import pandasql

conn = sqlite3.connect("flights.db")
cur = conn.cursor()

# %% [markdown]
# ## Exercise 1:
# Get all the columns from the airports table.

# %%
pd.read_sql('''
SELECT *
FROM airports
''', conn)
# Out:
#       index    id                               name             city  \
# 0         0     1                             Goroka           Goroka
# 1         1     2                             Madang           Madang
# 2         2     3                        Mount Hagen      Mount Hagen
# 3         3     4                             Nadzab           Nadzab
# 4         4     5         Port Moresby Jacksons Intl     Port Moresby
# ...     ...   ...                                ...              ...
# 8102   8102  9537    Mansons Landing Water Aerodrome  Mansons Landing
# 8103   8103  9538               Port McNeill Airport     Port McNeill
# 8104   8104  9539       Sullivan Bay Water Aerodrome     Sullivan Bay
# 8105   8105  9540               Deer Harbor Seaplane      Deer Harbor
# 8106   8106  9541  San Diego Old Town Transit Center        San Diego
#
#                country code  icao   latitude    longitude altitude offset dst  \
# ...

# %% [markdown]
# ## Exercise 2:
# Write a statement that will select the city column from the airports table.

# %%
pd.read_sql('''
SELECT City
FROM airports
''', conn)
# Out:
#                  city
# 0              Goroka
# 1              Madang
# 2         Mount Hagen
# 3              Nadzab
# 4        Port Moresby
# ...               ...
# 8102  Mansons Landing
# 8103     Port McNeill
# 8104     Sullivan Bay
# 8105      Deer Harbor
# 8106        San Diego
#
# [8107 rows x 1 columns]

# %% [markdown]
# ## Exercise 3:
# Select all the different values from the altitude column in the airports table.

# %%
pd.read_sql('''
SELECT altitude
FROM airports
''', conn)
# Out:
#      altitude
# 0        5282
# 1          20
# 2        5388
# 3         239
# 4         146
# ...       ...
# 8102        0
# 8103      225
# 8104        0
# 8105        0
# 8106        0
#
# [8107 rows x 1 columns]
